# %% [markdown]
# # Estudo prático - Classificadores (Comparação)
#
# #### Sabrina Otoni da Silva - 2023

# %%
# !pip install sklearn_extensions
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sklearn_extensions in /usr/local/lib/python3.7/dist-packages (0.0.2)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_extensions) (1.21.6)
# Requirement already satisfied: scipy>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_extensions) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.15 in /usr/local/lib/python3.7/dist-packages (from sklearn_extensions) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15->sklearn_extensions) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15->sklearn_extensions) (1.1.0)

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

"""
=====================
Classifier comparison
=====================

A comparison of a several classifiers in scikit-learn on synthetic datasets.
The point of this example is to illustrate the nature of decision boundaries
of different classifiers.
This should be taken with a grain of salt, as the intuition conveyed by
these examples does not necessarily carry over to real datasets.

Particularly in high-dimensional spaces, data can more easily be separated
linearly and the simplicity of classifiers such as naive Bayes and linear SVMs
might lead to better generalization than is achieved by other classifiers.

The plots show training points in solid colors and testing points
semi-transparent. The lower right shows the classification accuracy on the test
set.
"""
print(__doc__)


# Code source: Gaël Varoquaux
#              Andreas Müller
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification, make_blobs
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras import backend as K
from keras import metrics
from keras import regularizers
from tensorflow.python.client import device_lib

from xgboost import XGBClassifier

#pip install sklearn-extensions
#from sklearn_extensions.extreme_learning_machines.elm import GenELMClassifier
#from sklearn_extensions.extreme_learning_machines.random_layer import RBFRandomLayer, MLPRandomLayer
#conda install -c anaconda tensorflow-gpu

#Quantidade de Camadas Escondidas padrão
nh = 10

h = .02  # step size in the mesh

#Cria camada aleatório com função de ativação RBF
#srhl_rbf = RBFRandomLayer(n_hidden=nh*2, rbf_width=0.1, random_state=0)

names = [
        #"ELM - RBF",
         "Keras-MLP","Nearest Neighbors", "RBF SVM",
         "Decision Tree", "Random Forest",
         #"Neural Net - ReLU e Adam"
         "XGBoost",
         "Naive Bayes" ]

# kernel_regularizer=regularizers.l2(0.2))
#, kernel_regularizer=regularizers.l2(0.01)
kmlp = Sequential()
kmlp.add(Dense(8, input_dim=2, activation='relu',  kernel_initializer='normal'))
kmlp.add(Dense(128, activation='relu'))
kmlp.add(Dense(128, activation='relu'))
kmlp.add(Dense(1, activation='sigmoid'))
kmlp.compile(optimizer = "adam", loss='binary_crossentropy', metrics=['binary_accuracy'])

classifiers = [
    #GenELMClassifier(hidden_layer=srhl_rbf),
    kmlp,
    KNeighborsClassifier(3),
    SVC(gamma=2, C=1),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10),
    #MLPClassifier(alpha=0.5, max_iter=30000, hidden_layer_sizes=200, activation='relu', solver='adam', verbose=True ),
    XGBClassifier(n_estimators=100),
    GaussianNB()]

X, y = make_classification(n_features=2, n_redundant=0, n_informative=2,
                           random_state=1, n_clusters_per_class=1)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)
linearly_separable = (X, y)

datasets = [make_moons(noise=0.4, random_state=0),
            make_circles(noise=0.2, factor=0.5, random_state=1),
            linearly_separable,
            make_circles( noise=0.05, random_state=3)
            ]

figure = plt.figure(figsize=(27, 9))
i = 1
# iterate over datasets
for ds_cnt, ds in enumerate(datasets):
    # preprocess dataset, split into training and test part
    X, y = ds
    X = StandardScaler().fit_transform(X)
    X_train, X_test, y_train, y_test = \
        train_test_split(X, y, test_size=.4, random_state=42)

    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    # just plot the dataset first
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])
    ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
    if ds_cnt == 0:
        ax.set_title("Input data")
    # Plot the training points
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright,
               edgecolors='k')
    # Plot the testing points
    ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6,
               edgecolors='k')
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xticks(())
    ax.set_yticks(())
    i += 1

    # iterate over classifiers
    for name, clf in zip(names, classifiers):
        ax = plt.subplot(len(datasets), len(classifiers) + 1, i)

        if name == "Keras-MLP":
            clf.fit(X_train, y_train, epochs=100, batch_size=10  )
        else:
            clf.fit(X_train, y_train)

        if name == "Keras-MLP":
            score = clf.evaluate(X_test, y_test)
            score = score[1]
        else:
            score = clf.score(X_test, y_test)

        # Plot the decision boundary. For that, we will assign a color to each
        # point in the mesh [x_min, x_max]x[y_min, y_max].

        if hasattr(clf, "decision_function"):
            Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
        elif name == "Keras-MLP":
            #print(np.c_[xx.ravel(), yy.ravel()])
            aux = clf.predict(np.c_[xx.ravel(), yy.ravel()])
            Z =aux
        else:
            Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        ax.contourf(xx, yy, Z, cmap=cm, alpha=.8)

        # Plot the training points
        ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright,
                   edgecolors='k')
        # Plot the testing points
        ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright,
                   edgecolors='k', alpha=0.6)

        ax.set_xlim(xx.min(), xx.max())
        ax.set_ylim(yy.min(), yy.max())
        ax.set_xticks(())
        ax.set_yticks(())
        if ds_cnt == 0:
            ax.set_title(name)
        ax.text(xx.max() - .3, yy.min() + .3, ('%.2f' % score).lstrip('0'),
                size=15, horizontalalignment='right')
        i += 1

plt.tight_layout()
plt.show()
# Out:
# =====================
# Classifier comparison
# =====================
#
# A comparison of a several classifiers in scikit-learn on synthetic datasets.
# The point of this example is to illustrate the nature of decision boundaries
# of different classifiers.
# This should be taken with a grain of salt, as the intuition conveyed by
# these examples does not necessarily carry over to real datasets.
#
# Particularly in high-dimensional spaces, data can more easily be separated
# linearly and the simplicity of classifiers such as naive Bayes and linear SVMs
# might lead to better generalization than is achieved by other classifiers.
#
# The plots show training points in solid colors and testing points
# semi-transparent. The lower right shows the classification accuracy on the test
# set.
#
# Epoch 1/100
# 6/6 [==============================] - 1s 4ms/step - loss: 0.6900 - binary_accuracy: 0.7000
# Epoch 2/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6801 - binary_accuracy: 0.7667
# Epoch 3/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6689 - binary_accuracy: 0.7833
# Epoch 4/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6526 - binary_accuracy: 0.7833
# Epoch 5/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6304 - binary_accuracy: 0.7833
# Epoch 6/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6001 - binary_accuracy: 0.7833
# Epoch 7/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5666 - binary_accuracy: 0.7667
# Epoch 8/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5365 - binary_accuracy: 0.7833
# Epoch 9/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5007 - binary_accuracy: 0.7833
# Epoch 10/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4798 - binary_accuracy: 0.7833
# Epoch 11/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4585 - binary_accuracy: 0.7500
# Epoch 12/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4454 - binary_accuracy: 0.7500
# Epoch 13/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4420 - binary_accuracy: 0.7667
# Epoch 14/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4352 - binary_accuracy: 0.7667
# Epoch 15/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4308 - binary_accuracy: 0.7667
# Epoch 16/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4272 - binary_accuracy: 0.7833
# Epoch 17/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4224 - binary_accuracy: 0.7833
# Epoch 18/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4206 - binary_accuracy: 0.7833
# Epoch 19/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4157 - binary_accuracy: 0.7833
# Epoch 20/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4128 - binary_accuracy: 0.7833
# Epoch 21/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4176 - binary_accuracy: 0.7833
# Epoch 22/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4081 - binary_accuracy: 0.7833
# Epoch 23/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4074 - binary_accuracy: 0.7833
# Epoch 24/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4058 - binary_accuracy: 0.7667
# Epoch 25/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4013 - binary_accuracy: 0.7667
# Epoch 26/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4018 - binary_accuracy: 0.7833
# Epoch 27/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3978 - binary_accuracy: 0.7833
# Epoch 28/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3973 - binary_accuracy: 0.7833
# Epoch 29/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3934 - binary_accuracy: 0.8167
# Epoch 30/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3936 - binary_accuracy: 0.8000
# Epoch 31/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3899 - binary_accuracy: 0.8000
# Epoch 32/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3887 - binary_accuracy: 0.8167
# Epoch 33/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3860 - binary_accuracy: 0.8167
# Epoch 34/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3831 - binary_accuracy: 0.8000
# Epoch 35/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3810 - binary_accuracy: 0.8000
# Epoch 36/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3866 - binary_accuracy: 0.8000
# Epoch 37/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3775 - binary_accuracy: 0.8000
# Epoch 38/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3782 - binary_accuracy: 0.8000
# Epoch 39/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3759 - binary_accuracy: 0.8167
# Epoch 40/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3720 - binary_accuracy: 0.8167
# Epoch 41/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3686 - binary_accuracy: 0.8167
# Epoch 42/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3679 - binary_accuracy: 0.8167
# Epoch 43/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3671 - binary_accuracy: 0.8167
# Epoch 44/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3647 - binary_accuracy: 0.8167
# Epoch 45/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3640 - binary_accuracy: 0.8167
# Epoch 46/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3618 - binary_accuracy: 0.8167
# Epoch 47/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3594 - binary_accuracy: 0.8167
# Epoch 48/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3570 - binary_accuracy: 0.8167
# Epoch 49/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3573 - binary_accuracy: 0.8333
# Epoch 50/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3524 - binary_accuracy: 0.8333
# Epoch 51/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3538 - binary_accuracy: 0.8000
# Epoch 52/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3577 - binary_accuracy: 0.8167
# Epoch 53/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3487 - binary_accuracy: 0.8000
# Epoch 54/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3404 - binary_accuracy: 0.8000
# Epoch 55/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3391 - binary_accuracy: 0.8167
# Epoch 56/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3359 - binary_accuracy: 0.8333
# Epoch 57/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3312 - binary_accuracy: 0.8167
# Epoch 58/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3242 - binary_accuracy: 0.8167
# Epoch 59/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3202 - binary_accuracy: 0.8333
# Epoch 60/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3179 - binary_accuracy: 0.8333
# Epoch 61/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3183 - binary_accuracy: 0.8333
# Epoch 62/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3134 - binary_accuracy: 0.8333
# Epoch 63/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2990 - binary_accuracy: 0.8333
# Epoch 64/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2936 - binary_accuracy: 0.8333
# Epoch 65/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2884 - binary_accuracy: 0.8333
# Epoch 66/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2820 - binary_accuracy: 0.8333
# Epoch 67/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2737 - binary_accuracy: 0.8333
# Epoch 68/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2693 - binary_accuracy: 0.8333
# Epoch 69/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2643 - binary_accuracy: 0.8500
# Epoch 70/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2554 - binary_accuracy: 0.8667
# Epoch 71/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2526 - binary_accuracy: 0.8500
# Epoch 72/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2446 - binary_accuracy: 0.8833
# Epoch 73/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2398 - binary_accuracy: 0.8667
# Epoch 74/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2378 - binary_accuracy: 0.8667
# Epoch 75/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2322 - binary_accuracy: 0.9167
# Epoch 76/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2260 - binary_accuracy: 0.9000
# Epoch 77/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2216 - binary_accuracy: 0.9167
# Epoch 78/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2192 - binary_accuracy: 0.9000
# Epoch 79/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2127 - binary_accuracy: 0.9333
# Epoch 80/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2051 - binary_accuracy: 0.9167
# Epoch 81/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2114 - binary_accuracy: 0.9000
# Epoch 82/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2070 - binary_accuracy: 0.9500
# Epoch 83/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2071 - binary_accuracy: 0.9333
# Epoch 84/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1968 - binary_accuracy: 0.9000
# Epoch 85/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1947 - binary_accuracy: 0.9167
# Epoch 86/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1887 - binary_accuracy: 0.9333
# Epoch 87/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1902 - binary_accuracy: 0.9500
# Epoch 88/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1827 - binary_accuracy: 0.9500
# Epoch 89/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1760 - binary_accuracy: 0.9500
# Epoch 90/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1752 - binary_accuracy: 0.9500
# Epoch 91/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1787 - binary_accuracy: 0.9333
# Epoch 92/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1780 - binary_accuracy: 0.9500
# Epoch 93/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1747 - binary_accuracy: 0.9667
# Epoch 94/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1679 - binary_accuracy: 0.9500
# Epoch 95/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1643 - binary_accuracy: 0.9667
# Epoch 96/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1679 - binary_accuracy: 0.9500
# Epoch 97/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1616 - binary_accuracy: 0.9500
# Epoch 98/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1610 - binary_accuracy: 0.9667
# Epoch 99/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1616 - binary_accuracy: 0.9667
# Epoch 100/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1744 - binary_accuracy: 0.9500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3140 - binary_accuracy: 0.9500
# Epoch 1/100
# 6/6 [==============================] - 0s 4ms/step - loss: 2.3010 - binary_accuracy: 0.4667
# Epoch 2/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.2940 - binary_accuracy: 0.5500
# Epoch 3/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7668 - binary_accuracy: 0.6667
# Epoch 4/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6370 - binary_accuracy: 0.6500
# Epoch 5/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5336 - binary_accuracy: 0.6667
# Epoch 6/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5045 - binary_accuracy: 0.7000
# Epoch 7/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5172 - binary_accuracy: 0.7000
# Epoch 8/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4421 - binary_accuracy: 0.7500
# Epoch 9/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4193 - binary_accuracy: 0.7500
# Epoch 10/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4039 - binary_accuracy: 0.7667
# Epoch 11/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3908 - binary_accuracy: 0.7833
# Epoch 12/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3652 - binary_accuracy: 0.8167
# Epoch 13/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3395 - binary_accuracy: 0.7833
# Epoch 14/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3239 - binary_accuracy: 0.8333
# Epoch 15/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3091 - binary_accuracy: 0.8333
# Epoch 16/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2984 - binary_accuracy: 0.8333
# Epoch 17/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2879 - binary_accuracy: 0.8500
# Epoch 18/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2799 - binary_accuracy: 0.8667
# Epoch 19/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2665 - binary_accuracy: 0.9000
# Epoch 20/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2561 - binary_accuracy: 0.9000
# Epoch 21/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2644 - binary_accuracy: 0.8833
# Epoch 22/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2355 - binary_accuracy: 0.9167
# Epoch 23/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2372 - binary_accuracy: 0.9000
# Epoch 24/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2284 - binary_accuracy: 0.9500
# Epoch 25/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2220 - binary_accuracy: 0.9167
# Epoch 26/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2122 - binary_accuracy: 0.9167
# Epoch 27/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2067 - binary_accuracy: 0.9333
# Epoch 28/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2036 - binary_accuracy: 0.9500
# Epoch 29/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2016 - binary_accuracy: 0.9333
# Epoch 30/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1927 - binary_accuracy: 0.9667
# Epoch 31/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1916 - binary_accuracy: 0.9333
# Epoch 32/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1888 - binary_accuracy: 0.9333
# Epoch 33/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1827 - binary_accuracy: 0.9500
# Epoch 34/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1767 - binary_accuracy: 0.9500
# Epoch 35/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1790 - binary_accuracy: 0.9333
# Epoch 36/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1762 - binary_accuracy: 0.9333
# Epoch 37/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1697 - binary_accuracy: 0.9500
# Epoch 38/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1611 - binary_accuracy: 0.9833
# Epoch 39/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1669 - binary_accuracy: 0.9167
# Epoch 40/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1699 - binary_accuracy: 0.9333
# Epoch 41/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1548 - binary_accuracy: 0.9667
# Epoch 42/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1603 - binary_accuracy: 0.9833
# Epoch 43/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1549 - binary_accuracy: 0.9500
# Epoch 44/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1491 - binary_accuracy: 0.9667
# Epoch 45/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1509 - binary_accuracy: 0.9833
# Epoch 46/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1543 - binary_accuracy: 0.9333
# Epoch 47/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1502 - binary_accuracy: 0.9500
# Epoch 48/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1424 - binary_accuracy: 0.9833
# Epoch 49/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1389 - binary_accuracy: 0.9667
# Epoch 50/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1396 - binary_accuracy: 0.9667
# Epoch 51/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1343 - binary_accuracy: 0.9833
# Epoch 52/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1310 - binary_accuracy: 0.9833
# Epoch 53/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1320 - binary_accuracy: 0.9833
# Epoch 54/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1316 - binary_accuracy: 0.9833
# Epoch 55/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1286 - binary_accuracy: 0.9833
# Epoch 56/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1379 - binary_accuracy: 0.9333
# Epoch 57/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1205 - binary_accuracy: 0.9667
# Epoch 58/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1351 - binary_accuracy: 0.9667
# Epoch 59/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1198 - binary_accuracy: 1.0000
# Epoch 60/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1301 - binary_accuracy: 0.9333
# Epoch 61/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1339 - binary_accuracy: 0.9333
# Epoch 62/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1267 - binary_accuracy: 0.9667
# Epoch 63/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1257 - binary_accuracy: 0.9667
# Epoch 64/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1227 - binary_accuracy: 0.9667
# Epoch 65/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1150 - binary_accuracy: 0.9833
# Epoch 66/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1164 - binary_accuracy: 0.9833
# Epoch 67/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1098 - binary_accuracy: 0.9833
# Epoch 68/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1110 - binary_accuracy: 0.9833
# Epoch 69/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1099 - binary_accuracy: 1.0000
# Epoch 70/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1082 - binary_accuracy: 1.0000
# Epoch 71/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1064 - binary_accuracy: 1.0000
# Epoch 72/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1092 - binary_accuracy: 0.9833
# Epoch 73/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1048 - binary_accuracy: 1.0000
# Epoch 74/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1067 - binary_accuracy: 0.9833
# Epoch 75/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1048 - binary_accuracy: 0.9833
# Epoch 76/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0992 - binary_accuracy: 1.0000
# Epoch 77/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1000 - binary_accuracy: 1.0000
# Epoch 78/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1037 - binary_accuracy: 0.9833
# Epoch 79/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1017 - binary_accuracy: 0.9833
# Epoch 80/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1006 - binary_accuracy: 0.9833
# Epoch 81/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1012 - binary_accuracy: 0.9833
# Epoch 82/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1058 - binary_accuracy: 0.9833
# Epoch 83/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1072 - binary_accuracy: 0.9833
# Epoch 84/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1014 - binary_accuracy: 0.9667
# Epoch 85/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0921 - binary_accuracy: 1.0000
# Epoch 86/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0904 - binary_accuracy: 1.0000
# Epoch 87/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0874 - binary_accuracy: 1.0000
# Epoch 88/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0923 - binary_accuracy: 0.9833
# Epoch 89/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0861 - binary_accuracy: 1.0000
# Epoch 90/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0851 - binary_accuracy: 1.0000
# Epoch 91/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0873 - binary_accuracy: 0.9833
# Epoch 92/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0844 - binary_accuracy: 1.0000
# Epoch 93/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0853 - binary_accuracy: 1.0000
# Epoch 94/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0804 - binary_accuracy: 0.9833
# Epoch 95/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0862 - binary_accuracy: 1.0000
# Epoch 96/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0911 - binary_accuracy: 0.9833
# Epoch 97/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0897 - binary_accuracy: 1.0000
# Epoch 98/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0848 - binary_accuracy: 0.9833
# Epoch 99/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0823 - binary_accuracy: 1.0000
# Epoch 100/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0933 - binary_accuracy: 0.9667
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4369 - binary_accuracy: 0.8500
# Epoch 1/100
# 6/6 [==============================] - 0s 4ms/step - loss: 2.5172 - binary_accuracy: 0.5333
# Epoch 2/100
# 6/6 [==============================] - 0s 5ms/step - loss: 1.4338 - binary_accuracy: 0.6833
# Epoch 3/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7447 - binary_accuracy: 0.8167
# Epoch 4/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3276 - binary_accuracy: 0.8833
# Epoch 5/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2390 - binary_accuracy: 0.9333
# Epoch 6/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2061 - binary_accuracy: 0.9333
# Epoch 7/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1743 - binary_accuracy: 0.9333
# Epoch 8/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1605 - binary_accuracy: 0.9500
# Epoch 9/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1460 - binary_accuracy: 0.9500
# Epoch 10/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1319 - binary_accuracy: 0.9500
# Epoch 11/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1237 - binary_accuracy: 0.9500
# Epoch 12/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1178 - binary_accuracy: 0.9500
# Epoch 13/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1082 - binary_accuracy: 0.9500
# Epoch 14/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1037 - binary_accuracy: 0.9667
# Epoch 15/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0993 - binary_accuracy: 0.9667
# Epoch 16/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0974 - binary_accuracy: 0.9833
# Epoch 17/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0927 - binary_accuracy: 0.9833
# Epoch 18/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0926 - binary_accuracy: 0.9833
# Epoch 19/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0877 - binary_accuracy: 0.9833
# Epoch 20/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0844 - binary_accuracy: 0.9833
# Epoch 21/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0851 - binary_accuracy: 0.9833
# Epoch 22/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0838 - binary_accuracy: 0.9833
# Epoch 23/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0806 - binary_accuracy: 0.9833
# Epoch 24/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0785 - binary_accuracy: 0.9833
# Epoch 25/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0760 - binary_accuracy: 0.9833
# Epoch 26/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0750 - binary_accuracy: 0.9833
# Epoch 27/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0736 - binary_accuracy: 0.9833
# Epoch 28/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0740 - binary_accuracy: 0.9833
# Epoch 29/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0707 - binary_accuracy: 0.9833
# Epoch 30/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0692 - binary_accuracy: 0.9833
# Epoch 31/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0682 - binary_accuracy: 0.9833
# Epoch 32/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0678 - binary_accuracy: 0.9833
# Epoch 33/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0680 - binary_accuracy: 0.9833
# Epoch 34/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0662 - binary_accuracy: 0.9833
# Epoch 35/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0645 - binary_accuracy: 0.9833
# Epoch 36/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0629 - binary_accuracy: 0.9833
# Epoch 37/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0623 - binary_accuracy: 0.9833
# Epoch 38/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0620 - binary_accuracy: 0.9833
# Epoch 39/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0615 - binary_accuracy: 0.9833
# Epoch 40/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0597 - binary_accuracy: 0.9833
# Epoch 41/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0599 - binary_accuracy: 0.9833
# Epoch 42/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0589 - binary_accuracy: 0.9833
# Epoch 43/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0576 - binary_accuracy: 0.9833
# Epoch 44/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0562 - binary_accuracy: 0.9833
# Epoch 45/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0554 - binary_accuracy: 0.9833
# Epoch 46/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0557 - binary_accuracy: 0.9833
# Epoch 47/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0537 - binary_accuracy: 0.9833
# Epoch 48/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0544 - binary_accuracy: 0.9833
# Epoch 49/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0544 - binary_accuracy: 0.9833
# Epoch 50/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0516 - binary_accuracy: 0.9833
# Epoch 51/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0528 - binary_accuracy: 0.9833
# Epoch 52/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0516 - binary_accuracy: 0.9833
# Epoch 53/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0494 - binary_accuracy: 0.9833
# Epoch 54/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0527 - binary_accuracy: 0.9833
# Epoch 55/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0499 - binary_accuracy: 0.9833
# Epoch 56/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0482 - binary_accuracy: 0.9833
# Epoch 57/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0483 - binary_accuracy: 0.9833
# Epoch 58/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0481 - binary_accuracy: 0.9833
# Epoch 59/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0471 - binary_accuracy: 0.9833
# Epoch 60/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0457 - binary_accuracy: 0.9833
# Epoch 61/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0448 - binary_accuracy: 0.9833
# Epoch 62/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0454 - binary_accuracy: 0.9833
# Epoch 63/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0440 - binary_accuracy: 0.9833
# Epoch 64/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0427 - binary_accuracy: 0.9833
# Epoch 65/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0432 - binary_accuracy: 0.9833
# Epoch 66/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0420 - binary_accuracy: 0.9833
# Epoch 67/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0421 - binary_accuracy: 0.9833
# Epoch 68/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0427 - binary_accuracy: 0.9833
# Epoch 69/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0405 - binary_accuracy: 0.9833
# Epoch 70/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0413 - binary_accuracy: 0.9833
# Epoch 71/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0412 - binary_accuracy: 0.9833
# Epoch 72/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0402 - binary_accuracy: 0.9833
# Epoch 73/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0398 - binary_accuracy: 0.9833
# Epoch 74/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0396 - binary_accuracy: 0.9833
# Epoch 75/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0389 - binary_accuracy: 0.9833
# Epoch 76/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0384 - binary_accuracy: 0.9833
# Epoch 77/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0394 - binary_accuracy: 0.9833
# Epoch 78/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0380 - binary_accuracy: 0.9833
# Epoch 79/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0374 - binary_accuracy: 0.9833
# Epoch 80/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0369 - binary_accuracy: 0.9833
# Epoch 81/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0375 - binary_accuracy: 0.9833
# Epoch 82/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0365 - binary_accuracy: 0.9833
# Epoch 83/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0371 - binary_accuracy: 0.9833
# Epoch 84/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0358 - binary_accuracy: 0.9833
# Epoch 85/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0354 - binary_accuracy: 0.9833
# Epoch 86/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0358 - binary_accuracy: 0.9833
# Epoch 87/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0355 - binary_accuracy: 0.9833
# Epoch 88/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0344 - binary_accuracy: 0.9833
# Epoch 89/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0348 - binary_accuracy: 0.9833
# Epoch 90/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0346 - binary_accuracy: 0.9833
# Epoch 91/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0347 - binary_accuracy: 0.9833
# Epoch 92/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0336 - binary_accuracy: 0.9833
# Epoch 93/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0330 - binary_accuracy: 0.9833
# Epoch 94/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0327 - binary_accuracy: 0.9833
# Epoch 95/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0322 - binary_accuracy: 0.9833
# Epoch 96/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0324 - binary_accuracy: 0.9833
# Epoch 97/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0324 - binary_accuracy: 0.9833
# Epoch 98/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0324 - binary_accuracy: 0.9833
# Epoch 99/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0325 - binary_accuracy: 0.9833
# Epoch 100/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0319 - binary_accuracy: 0.9833
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5726 - binary_accuracy: 0.8750
# Epoch 1/100
# 6/6 [==============================] - 0s 3ms/step - loss: 4.7590 - binary_accuracy: 0.5000
# Epoch 2/100
# 6/6 [==============================] - 0s 3ms/step - loss: 2.5720 - binary_accuracy: 0.4833
# Epoch 3/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.2282 - binary_accuracy: 0.4833
# Epoch 4/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7445 - binary_accuracy: 0.4667
# Epoch 5/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6983 - binary_accuracy: 0.5167
# Epoch 6/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7003 - binary_accuracy: 0.5000
# Epoch 7/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7017 - binary_accuracy: 0.5333
# Epoch 8/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6957 - binary_accuracy: 0.5500
# Epoch 9/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6879 - binary_accuracy: 0.6333
# Epoch 10/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6799 - binary_accuracy: 0.6333
# Epoch 11/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6763 - binary_accuracy: 0.6167
# Epoch 12/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6735 - binary_accuracy: 0.6333
# Epoch 13/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6713 - binary_accuracy: 0.6167
# Epoch 14/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6670 - binary_accuracy: 0.6333
# Epoch 15/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6620 - binary_accuracy: 0.6333
# Epoch 16/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6590 - binary_accuracy: 0.6500
# Epoch 17/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6546 - binary_accuracy: 0.6667
# Epoch 18/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6515 - binary_accuracy: 0.6667
# Epoch 19/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6494 - binary_accuracy: 0.6667
# Epoch 20/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6452 - binary_accuracy: 0.6667
# Epoch 21/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6427 - binary_accuracy: 0.6833
# Epoch 22/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6385 - binary_accuracy: 0.6833
# Epoch 23/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6362 - binary_accuracy: 0.7000
# Epoch 24/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6326 - binary_accuracy: 0.6833
# Epoch 25/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6332 - binary_accuracy: 0.7000
# Epoch 26/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6261 - binary_accuracy: 0.7333
# Epoch 27/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6232 - binary_accuracy: 0.7167
# Epoch 28/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6219 - binary_accuracy: 0.7333
# Epoch 29/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6175 - binary_accuracy: 0.7333
# Epoch 30/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6158 - binary_accuracy: 0.7333
# Epoch 31/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6116 - binary_accuracy: 0.7333
# Epoch 32/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6089 - binary_accuracy: 0.7167
# Epoch 33/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6037 - binary_accuracy: 0.7333
# Epoch 34/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6003 - binary_accuracy: 0.7333
# Epoch 35/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5976 - binary_accuracy: 0.7500
# Epoch 36/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5938 - binary_accuracy: 0.7500
# Epoch 37/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5889 - binary_accuracy: 0.7500
# Epoch 38/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5862 - binary_accuracy: 0.7667
# Epoch 39/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5832 - binary_accuracy: 0.7667
# Epoch 40/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5809 - binary_accuracy: 0.7667
# Epoch 41/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5738 - binary_accuracy: 0.7667
# Epoch 42/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5701 - binary_accuracy: 0.7667
# Epoch 43/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5656 - binary_accuracy: 0.7667
# Epoch 44/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5605 - binary_accuracy: 0.7667
# Epoch 45/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5576 - binary_accuracy: 0.7667
# Epoch 46/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5529 - binary_accuracy: 0.7667
# Epoch 47/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5487 - binary_accuracy: 0.7667
# Epoch 48/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5442 - binary_accuracy: 0.7833
# Epoch 49/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5387 - binary_accuracy: 0.7667
# Epoch 50/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5341 - binary_accuracy: 0.8000
# Epoch 51/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5285 - binary_accuracy: 0.8000
# Epoch 52/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5217 - binary_accuracy: 0.8000
# Epoch 53/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5180 - binary_accuracy: 0.8000
# Epoch 54/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5090 - binary_accuracy: 0.8000
# Epoch 55/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5055 - binary_accuracy: 0.8000
# Epoch 56/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4975 - binary_accuracy: 0.8000
# Epoch 57/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4954 - binary_accuracy: 0.7833
# Epoch 58/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4938 - binary_accuracy: 0.7833
# Epoch 59/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4784 - binary_accuracy: 0.8000
# Epoch 60/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4735 - binary_accuracy: 0.8333
# Epoch 61/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4659 - binary_accuracy: 0.8000
# Epoch 62/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4568 - binary_accuracy: 0.8167
# Epoch 63/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4428 - binary_accuracy: 0.8333
# Epoch 64/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4294 - binary_accuracy: 0.8667
# Epoch 65/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4187 - binary_accuracy: 0.8667
# Epoch 66/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4088 - binary_accuracy: 0.9167
# Epoch 67/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3905 - binary_accuracy: 0.9000
# Epoch 68/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3845 - binary_accuracy: 0.8667
# Epoch 69/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3673 - binary_accuracy: 0.9000
# Epoch 70/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3572 - binary_accuracy: 0.9333
# Epoch 71/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3499 - binary_accuracy: 0.9333
# Epoch 72/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3379 - binary_accuracy: 0.9333
# Epoch 73/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3265 - binary_accuracy: 0.9167
# Epoch 74/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3147 - binary_accuracy: 0.9500
# Epoch 75/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3094 - binary_accuracy: 0.9167
# Epoch 76/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3026 - binary_accuracy: 0.9167
# Epoch 77/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3023 - binary_accuracy: 0.9500
# Epoch 78/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2934 - binary_accuracy: 0.9500
# Epoch 79/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2749 - binary_accuracy: 0.9167
# Epoch 80/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2721 - binary_accuracy: 0.9500
# Epoch 81/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2584 - binary_accuracy: 0.9333
# Epoch 82/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2492 - binary_accuracy: 0.9667
# Epoch 83/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2478 - binary_accuracy: 0.9667
# Epoch 84/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2388 - binary_accuracy: 0.9667
# Epoch 85/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2297 - binary_accuracy: 0.9833
# Epoch 86/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2250 - binary_accuracy: 0.9500
# Epoch 87/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2214 - binary_accuracy: 0.9667
# Epoch 88/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2116 - binary_accuracy: 0.9833
# Epoch 89/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2083 - binary_accuracy: 0.9667
# Epoch 90/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2134 - binary_accuracy: 0.9833
# Epoch 91/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2028 - binary_accuracy: 0.9500
# Epoch 92/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2091 - binary_accuracy: 0.9333
# Epoch 93/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1906 - binary_accuracy: 1.0000
# Epoch 94/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1855 - binary_accuracy: 0.9667
# Epoch 95/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1774 - binary_accuracy: 0.9833
# Epoch 96/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1740 - binary_accuracy: 1.0000
# Epoch 97/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1708 - binary_accuracy: 1.0000
# Epoch 98/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1695 - binary_accuracy: 1.0000
# Epoch 99/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1647 - binary_accuracy: 0.9667
# Epoch 100/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1601 - binary_accuracy: 0.9833
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2523 - binary_accuracy: 0.9250
